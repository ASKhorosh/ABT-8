# %%
import pandas as pd
import numpy as np

# %%
ab = pd.read_csv('Netology_A_B-testing_HW_1.csv',na_values='?')
ab.head()
# Out:
#    Unnamed: 0        date  user_id  hour  app_opened  price_seen  order_made  \
# 0           0  2020-05-21   867689    12           1           1           1
# 1           1  2020-05-23   752172     5           1           1           1
# 2           2  2020-05-20   486559    15           1           1           1
# 3           3  2020-05-19   304024     0           1           1           1
# 4           4  2020-05-23   139420     0           1           1           1
#
#       surge  ride_completed  user_cancelled  age       os  city_center_order  \
# 0  no surge               1               0   20      iOS                  0
# 1  no surge               1               0   37  Android                  1
# 2  no surge               1               0   47  Android                  0
# 3  no surge               1               0   59  Android                  1
# 4  no surge               1               0   19  Android                  0
#
#   order_class   distance     rfm
# ...

# %% [markdown]
# # Гипотеза 1
# Если мы перестанем показывать информацию о надбавке за повышенный спрос для тех, кто едет не из центра, в случае запроса цены на поездку, то конверсия в заказ на шаге показа цены увеличится на 14%, потому что среди данной группы конверсия 82% среди тех, кто не видит отметку о повышенном спросе и 68% среди тех, кто видит пометку.
# **Генеральная совокупность:** Пользователи, совершающие поездки не из центра

# %%
no_city_center = ab.loc[(ab['city_center_order'] == 0)]
no_city_center
# Out:
#         Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 0                0  2020-05-21   867689    12           1           1
# 2                2  2020-05-20   486559    15           1           1
# 4                4  2020-05-23   139420     0           1           1
# 8                8  2020-05-23   931492    20           1           0
# 10              10  2020-05-23   464055    20           1           1
# ...            ...         ...      ...   ...         ...         ...
# 101492      101492  2020-05-21   213028    13           1           1
# 101495      101495  2020-05-24   288445    16           1           1
# 101497      101497  2020-05-23   784442     1           1           1
# 101498      101498  2020-05-20   232993    13           1           1
# 101499      101499  2020-05-22   337225    21           1           1
#
#         order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
#считаем показатели завершения заказа по юзерам, т.к. именно на эту метрику мы хотим влиять
no_city_center_group.order_made = no_city_center.groupby('user_id', as_index=False)['order_made'].sum()['order_made']
no_city_center_group
# Out:
#        user_id  Unnamed: 0        date  hour  app_opened  price_seen  \
# 0       100093       43053  2020-05-19    15           1           1
# 1       100118       15284  2020-05-24    23           1           1
# 2       100134       36594  2020-05-22    17           1           1
# 3       100166       12716  2020-05-19    11           1           1
# 4       100255        2793  2020-05-19    13           1           1
# ...        ...         ...         ...   ...         ...         ...
# 20336   999825       36482  2020-05-21    16           1           1
# 20337   999878       45801  2020-05-21    19           1           1
# 20338   999945       98963  2020-05-23    14           1           1
# 20339   999962       28334  2020-05-23    14           1           0
# 20340   999978       16211  2020-05-24    19           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
import random
pd.options.mode.chained_assignment = None
no_city_center_group['randNumGroup'] = np.random.randint(1,3, size=len(no_city_center_group))
no_city_center_group
# Out:
#        user_id  Unnamed: 0        date  hour  app_opened  price_seen  \
# 0       100093       43053  2020-05-19    15           1           1
# 1       100118       15284  2020-05-24    23           1           1
# 2       100134       36594  2020-05-22    17           1           1
# 3       100166       12716  2020-05-19    11           1           1
# 4       100255        2793  2020-05-19    13           1           1
# ...        ...         ...         ...   ...         ...         ...
# 20336   999825       36482  2020-05-21    16           1           1
# 20337   999878       45801  2020-05-21    19           1           1
# 20338   999945       98963  2020-05-23    14           1           1
# 20339   999962       28334  2020-05-23    14           1           0
# 20340   999978       16211  2020-05-24    19           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
no_city_center_group1 = no_city_center_group.loc[(no_city_center_group['randNumGroup'] == 1)]
no_city_center_group1
# Out:
#        user_id  Unnamed: 0        date  hour  app_opened  price_seen  \
# 0       100093       43053  2020-05-19    15           1           1
# 3       100166       12716  2020-05-19    11           1           1
# 6       100303       39374  2020-05-20    11           1           1
# 8       100375       56551  2020-05-18     8           1           1
# 9       100405       57208  2020-05-19     7           1           0
# ...        ...         ...         ...   ...         ...         ...
# 20324   999141       17734  2020-05-19     9           1           1
# 20325   999182       19684  2020-05-21     3           1           1
# 20331   999593       56804  2020-05-20     6           1           0
# 20335   999682        1740  2020-05-18    16           1           1
# 20338   999945       98963  2020-05-23    14           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
no_city_center_group2 = no_city_center_group.loc[(no_city_center_group['randNumGroup'] == 2)]
no_city_center_group2
# Out:
#        user_id  Unnamed: 0        date  hour  app_opened  price_seen  \
# 1       100118       15284  2020-05-24    23           1           1
# 2       100134       36594  2020-05-22    17           1           1
# 4       100255        2793  2020-05-19    13           1           1
# 5       100275       13132  2020-05-19    18           1           0
# 7       100313       90443  2020-05-24    19           1           1
# ...        ...         ...         ...   ...         ...         ...
# 20334   999670       25057  2020-05-22    19           1           1
# 20336   999825       36482  2020-05-21    16           1           1
# 20337   999878       45801  2020-05-21    19           1           1
# 20339   999962       28334  2020-05-23    14           1           0
# 20340   999978       16211  2020-05-24    19           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
print (len(no_city_center_group1) - len (no_city_center_group2))
# Out:
# -9

# %%
import scipy.stats as stats
#попробуем сравнить группы по показателю завершения поездки
t, p_value = stats.ttest_ind(no_city_center_group1.order_made, no_city_center_group2.order_made) #Критерий Стьюдента (t-test)
t, p_value
# Out:
# (0.5956796513981611, 0.5513958826944951)

# %%
stats.ttest_ind(no_city_center_group1.order_made, no_city_center_group2.order_made, equal_var = False)
# Out:
# Ttest_indResult(statistic=0.5956800353111451, pvalue=0.5513956261814753)

# %%
alpha = 0.05
if p_value < alpha:
    print('p-value меньше уровня значимости -- значит гипотезу о том, что выборки различаются, следует отвергнуть')
else: 
    print('p-value больше уровня значимости -- значит гипотезу о том, что выборки различаются, следует принять')
# Out:
# p-value больше уровня значимости -- значит гипотезу о том, что выборки различаются, следует принять

# %%
#по показателю завершения заказов группы значимо отличаются, распределение не имеет нормальную форму
    #нужно, либо поменять определяющую метрику, либо пересортировать группы

import matplotlib.pyplot as plt
plt.hist(no_city_center_group1.order_made, bins=15); 
plt.hist(no_city_center_group2.order_made, bins=15);

# %% [markdown]
# # Гипотеза 2
# Если мы изменим экран отмены поездки для пользователей андроид, в случае попытки отмены уже созданного заказа, то конверсия в завершенные поездки увеличится на 4,2%, потому что конверсия на этом шаге у андроида на 4,2% меньше, чем у айос, попробуем сделать экран максимально похожим на айос, или наоборот, сделаем экран с привычными паттернами именно для андроид.
# **Генеральная совокупность:** Пользователи платформы андроид

# %%
Android = ab.loc[(ab['os'] == 'Android')]
Android
# Out:
#         Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 1                1  2020-05-23   752172     5           1           1
# 2                2  2020-05-20   486559    15           1           1
# 3                3  2020-05-19   304024     0           1           1
# 4                4  2020-05-23   139420     0           1           1
# 5                5  2020-05-21   139455     5           1           0
# ...            ...         ...      ...   ...         ...         ...
# 101489      101489  2020-05-20   969159    22           1           0
# 101490      101490  2020-05-20   780673    20           1           1
# 101491      101491  2020-05-21   456333    10           1           1
# 101495      101495  2020-05-24   288445    16           1           1
# 101499      101499  2020-05-22   337225    21           1           1
#
#         order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
Android_group = Android
Android_group
# Out:
#         Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 1                1  2020-05-23   752172     5           1           1
# 2                2  2020-05-20   486559    15           1           1
# 3                3  2020-05-19   304024     0           1           1
# 4                4  2020-05-23   139420     0           1           1
# 5                5  2020-05-21   139455     5           1           0
# ...            ...         ...      ...   ...         ...         ...
# 101489      101489  2020-05-20   969159    22           1           0
# 101490      101490  2020-05-20   780673    20           1           1
# 101491      101491  2020-05-21   456333    10           1           1
# 101495      101495  2020-05-24   288445    16           1           1
# 101499      101499  2020-05-22   337225    21           1           1
#
#         order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
#считаем показатели завершения поездки по юзерам, т.к. именно на эту метрику мы хотим влиять
Android_group.ride_completed = Android.groupby('user_id', as_index=False)['ride_completed'].sum()['ride_completed']
Android_group
# Out:
#         Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 1                1  2020-05-23   752172     5           1           1
# 2                2  2020-05-20   486559    15           1           1
# 3                3  2020-05-19   304024     0           1           1
# 4                4  2020-05-23   139420     0           1           1
# 5                5  2020-05-21   139455     5           1           0
# ...            ...         ...      ...   ...         ...         ...
# 101489      101489  2020-05-20   969159    22           1           0
# 101490      101490  2020-05-20   780673    20           1           1
# 101491      101491  2020-05-21   456333    10           1           1
# 101495      101495  2020-05-24   288445    16           1           1
# 101499      101499  2020-05-22   337225    21           1           1
#
#         order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
A = Android_group.dropna()
A
# Out:
#        Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 1               1  2020-05-23   752172     5           1           1
# 2               2  2020-05-20   486559    15           1           1
# 3               3  2020-05-19   304024     0           1           1
# 4               4  2020-05-23   139420     0           1           1
# 7               7  2020-05-22   682337     2           1           1
# ...           ...         ...      ...   ...         ...         ...
# 22144       22144  2020-05-23   967235    20           1           1
# 22145       22145  2020-05-22   838746    23           1           1
# 22147       22147  2020-05-24   616113    22           1           1
# 22149       22149  2020-05-24   648787    19           1           1
# 22153       22153  2020-05-20   843705    13           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
A['randNumGroup'] = np.random.randint(1,3, size=len(A))
A
# Out:
#        Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 1               1  2020-05-23   752172     5           1           1
# 2               2  2020-05-20   486559    15           1           1
# 3               3  2020-05-19   304024     0           1           1
# 4               4  2020-05-23   139420     0           1           1
# 7               7  2020-05-22   682337     2           1           1
# ...           ...         ...      ...   ...         ...         ...
# 22144       22144  2020-05-23   967235    20           1           1
# 22145       22145  2020-05-22   838746    23           1           1
# 22147       22147  2020-05-24   616113    22           1           1
# 22149       22149  2020-05-24   648787    19           1           1
# 22153       22153  2020-05-20   843705    13           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
Android_1 = A.loc[(A['randNumGroup'] == 1)]
Android_1
# Out:
#        Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 11             11  2020-05-24   370093    12           1           1
# 13             13  2020-05-19   786923    23           1           1
# 16             16  2020-05-23   990097     2           1           1
# 18             18  2020-05-19   393096    23           1           1
# 19             19  2020-05-20   320419     3           1           1
# ...           ...         ...      ...   ...         ...         ...
# 22134       22134  2020-05-19   933629    10           1           1
# 22136       22136  2020-05-21   570068    16           1           1
# 22142       22142  2020-05-23   917521     1           1           1
# 22145       22145  2020-05-22   838746    23           1           1
# 22147       22147  2020-05-24   616113    22           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
Android_2 = A.loc[(A['randNumGroup'] == 2)]
Android_2
# Out:
#        Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 1               1  2020-05-23   752172     5           1           1
# 2               2  2020-05-20   486559    15           1           1
# 3               3  2020-05-19   304024     0           1           1
# 4               4  2020-05-23   139420     0           1           1
# 7               7  2020-05-22   682337     2           1           1
# ...           ...         ...      ...   ...         ...         ...
# 22140       22140  2020-05-18   474581    23           1           1
# 22143       22143  2020-05-20   819402    10           1           1
# 22144       22144  2020-05-23   967235    20           1           1
# 22149       22149  2020-05-24   648787    19           1           1
# 22153       22153  2020-05-20   843705    13           1           1
#
#        order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
print (len(Android_1) - len (Android_2))
# Out:
# 19

# %%
#попробуем сравнить группы по завершению поездки
t, p_value = stats.ttest_ind(Android_1.ride_completed, Android_2.ride_completed) #Критерий Стьюдента (t-test)
t, p_value
# Out:
# (0.9952116347102008, 0.3196555648113635)

# %%
stats.ttest_ind(Android_1.ride_completed, Android_2.ride_completed, equal_var = False)
# Out:
# Ttest_indResult(statistic=0.9952674642160159, pvalue=0.3196284372758233)

# %%
alpha = 0.05
if p_value < alpha:
    print('p-value меньше уровня значимости -- значит гипотезу о том, что выборки различаются, следует отвергнуть')
else: 
    print('p-value больше уровня значимости -- значит гипотезу о том, что выборки различаются, следует принять')
# Out:
# p-value больше уровня значимости -- значит гипотезу о том, что выборки различаются, следует принять

# %%
#среди пользователей андроида по показателю завершения поездки группы значимо отличаются, распределение не имеет нормальную форму
    #нужно, либо поменять характерную метрику для группы, либо, помимо завершения поездки взять что-то еще, например показатели отмены

plt.hist(Android_1.ride_completed, bins=10); 
plt.hist(Android_2.ride_completed, bins=10);
